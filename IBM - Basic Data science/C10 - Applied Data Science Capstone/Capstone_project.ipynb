# %% [markdown]
# # Capstone Project

# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project, we will find an optimal location for a specific type of commercial establishment, lets say we were hired to find one or more potencial locations to install a **Hotel** in **Paris**.
#
# We will search for areas with the **minimum amount of Hotels as possible** and **as close to the city center as possible**

# %% [markdown]
# ## Data

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing Hotels in the area
# * minimum distance to Hotels in the area, if any
# * distance of area from city center
#
# We decided to use regularly spaced grid of locations, centered around city center, to define our areas.
#
# Following data sources will be needed to extract/generate the required information:
# * to get the coordinates of the center of Paris we will use the **geopy** dependencie, and with those coordinates we will create all the other area's coordinates spread equally around Paris
# * number of Hotels in every area will be obtained using **Foursquare API**

# %% [markdown]
# Before any action, we will import almost all the dependencies we will be using upon this project

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Now, the Notre-Dame is right on the center of Paris, so we will take its coordinates to create all the areas

# %%
address = '6 Parvis Notre-Dame - Pl. Jean-Paul II, 75004 Paris, France'

geolocator = Nominatim(user_agent="project_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Paris are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Paris are 48.85293705, 2.3500501225000026.

# %% [markdown]
# We create those functions to explore Paris ass an hexagonal grid of cells

# %%
#!pip install shapely
import shapely.geometry

#!pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

# %% [markdown]
# Now let's create a grid of area candidates, equaly spaced, centered around city center and within ~8km from Alexanderplatz. Our neighborhoods will be defined as circular areas with a radius of 300 meters, so our neighborhood centers will be 600 meters apart.

# %%
paris_center = [latitude, longitude]
paris_center
# Out:
# [48.85293705, 2.3500501225000026]

# %% [markdown]
# this code was used and modified to fit our porpuses,

# %% [raw]
# paris_center_x, paris_center_y = lonlat_to_xy(paris_center[1], paris_center[0]) # City center in Cartesian coordinates
#
#
# k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
# x_min = paris_center_x - 6000
# x_step = 600
# y_min = paris_center_y - 6000 - (int(21/k)*k*600 - 12000)/2
# y_step = 600 * k
#
# latitudes = []
# longitudes = []
# distances_from_center = []
# xs = []
# ys = []
#
# for i in range(0, int(21/k)):
#     y = y_min + i * y_step
#     x_offset = 300 if i%2==0 else 0
#     for j in range(0, 21):
#         x = x_min + j * x_step + x_offset
#         distance_from_center = calc_xy_distance(paris_center_x, paris_center_y, x, y)
#         if (distance_from_center <= (6001)):
#             lon, lat = xy_to_lonlat(x, y)
#             latitudes.append(lat)
#             longitudes.append(lon)
#             distances_from_center.append(distance_from_center)
#             xs.append(x)
#             ys.append(y)

# %%
paris_center_x, paris_center_y = lonlat_to_xy(paris_center[1], paris_center[0]) # City center in Cartesian coordinates

circle_diameter = 600
hexagon_with = 8000
n_circles = 21
n_circles = int(((hexagon_with*2)/circle_diameter)) + 1
k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = paris_center_x - hexagon_with
x_step = circle_diameter
y_min = paris_center_y - hexagon_with*k
y_step = circle_diameter * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
# Out:
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)

# %%
for i in range(0, int(n_circles/k)):
    y = y_min + i * y_step
    x_offset = (circle_diameter/2) if i%2==0 else 0
    for j in range(0, n_circles):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(paris_center_x, paris_center_y, x, y)
        if (distance_from_center <= (hexagon_with+1)):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)
# Out:
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# ...
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)

# %%
print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 630 candidate neighborhood centers generated.

# %%
map_paris = folium.Map(location=[latitude, longitude], zoom_start=13)
folium.Marker(location=[latitude, longitude], popup='Notre-Dame').add_to(map_paris)
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_berlin) 
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_paris)
    #folium.Marker([lat, lon]).add_to(map_berlin)
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2828bbd33edd47c79f943a8e9eee62ad%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2828bbd33edd47c79f943a8e9eee62ad%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2828bbd33edd47c79f943a8e9eee62ad%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2828bbd33edd47c79f943a8e9eee62ad%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.85293705%2C%202.3500501225000026%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Now, lets find and address to our areas that we got and put all this information in a DataFrame

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    input_coords = f'{lat}, {lon}'
    location = geolocator.reverse(input_coords)
    addresses.append(location.address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
addresses[350:380]
# Out:
# ["Le Bistrot de Paris, 33, Rue de Lille, Quartier Saint-Thomas-d'Aquin, Paris 7e Arrondissement, Paris, Île-de-France, France métropolitaine, 75007, France",
#  "Jardin de l'Infante, Ascenseur C, Quartier Saint-Germain-l'Auxerrois, Paris 1er Arrondissement, Paris, Île-de-France, France métropolitaine, 75001, France",
#  'Restaurant Saudade, Rue des Bourdonnais, Quartier des Halles, Quartier Les Halles, Paris 1er Arrondissement, Paris, Île-de-France, France métropolitaine, 75001, France',
#  "Rue Geoffroy l'Angevin (Fondation Galeries Lafayette), Rue Beaubourg, Beaubourg, Quartier Saint-Merri, Paris 4e Arrondissement, Paris, Île-de-France, France métropolitaine, France",
#  '21, Rue Charlot, Quartier des Enfants-Rouges, Paris 3e Arrondissement, Paris, Île-de-France, France métropolitaine, 75003, France',
#  '7, Passage Saint-Pierre Amelot, Quartier Saint-Ambroise, Paris 11e Arrondissement, Paris, Île-de-France, France métropolitaine, 75011, France',
#  '12, Passage Saint-Ambroise, Quartier Saint-Ambroise, Paris 11e Arrondissement, Paris, Île-de-France, France métropolitaine, 75011, France',
#  'Allée Mireille Knoll, Quartier Saint-Ambroise, Paris 11e Arrondissement, Paris, Île-de-France, France métropolitaine, 75011, France',
#  "Rue Villiers de l'Isle Adam, Quartier du Père-Lachaise, Paris 20e Arrondissement, Paris, Île-de-France, France métropolitaine, 75020, France",
#  'Hôpital Tenon, Rue Le Bua, Campagne à Paris, Quartier Saint-Fargeau, Paris 20e Arrondissement, Paris, Île-de-France, France métropolitaine, 75020, France',
#  'Ma Campagne à Paris, Boulevard Mortier, Campagne à Paris, Quartier Saint-Fargeau, Paris 20e Arrondissement, Paris, Île-de-France, France métropolitaine, 75020, France',
#  'Médiathèque de Bagnolet, Place Salvador Allende, Centre, Bagnolet, Bobigny, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93170, France',
#  'Stade des Malassis, Rue Charles Delescluze, Malassis, Bagnolet, Bobigny, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93170, France',
#  '1bis, Rue du Marais, Villiers - Barbusse, Montreuil, Bobigny, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93100, France',
#  'Rue des Margottes, Villiers - Barbusse, Montreuil, Bobigny, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93100, France',
#  'Rue Jean-Baptiste Lamarck, Signac - Murs-à-Pêches, Montreuil, Bobigny, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93100, France',
#  "Parcours de Santé, Quartier d'Auteuil, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France",
#  "Parcours de Santé, Quartier d'Auteuil, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France",
#  "Hippodrome d'Auteuil, Rue Raffet, Quartier d'Auteuil, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France",
#  '92, Rue du Ranelagh, Quartier de la Muette, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France',
#  '7, Rue Talma, Quartier de la Muette, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France',
#  "5, Rue Raynouard, Quartier d'Auteuil, Paris 16e Arrondissement, Paris, Île-de-France, France métropolitaine, 75016, France",
#  'Port de Suffren, Quai Jacques Chirac, Quartier de Grenelle, Paris 15e Arrondissement, Paris, Île-de-France, France métropolitaine, 75015, France',
#  "L'Howea, Rue de Monttessuy, Quartier du Gros-Caillou, Paris 7e Arrondissement, Paris, Île-de-France, France métropolitaine, 75007, France",
#  "129, Rue de l'Université, Quartier des Invalides, Paris 7e Arrondissement, Paris, Île-de-France, France métropolitaine, 75007, France",
#  "Ministère de l'Europe et des Affaires étrangères, Rue Robert Esnault-Pelterie, Quartier des Invalides, Paris 7e Arrondissement, Paris, Île-de-France, France métropolitaine, 75007, France",
#  "Port des Tuileries, Quai des Tuileries, Quartier Saint-Germain-l'Auxerrois, Paris 1er Arrondissement, Paris, Île-de-France, France métropolitaine, France",
#  'Palais du Louvre, Rue du Colonel Driant, Quartier des Halles, Quartier Les Halles, Paris 1er Arrondissement, Paris, Île-de-France, France métropolitaine, 75001, France',
#  'Panik Room, Rue Croix des Petits Champs, Quartier Les Halles, Paris 1er Arrondissement, Paris, Île-de-France, France métropolitaine, 75001, France',
#  '49, Rue Greneta, Quartier des Arts-et-Métiers, Paris 3e Arrondissement, Paris, Île-de-France, France métropolitaine, 75003, France']

# %%
len(addresses)
# Out:
# 630

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head(10)
# Out:
#                                              Address   Latitude  Longitude  \
# 0  3, Rue du Président Roosevelt, Bourg-la-Reine,...  48.786934   2.319107
# 1  61, Avenue de la Division Leclerc, Cité-Jardin...  48.787825   2.327076
# 2  36, Allée Eugène Belgrand, Cachan, Arrondissem...  48.788716   2.335046
# 3  Rue de la Concorde, Cachan, Arrondissement de ...  48.789606   2.343016
# 4  7, Allée Sonia Delaunay, Villejuif, Arrondisse...  48.790495   2.350986
# 5  Centre Hospitalier Paul Guiraud, Avenue de la ...  48.791384   2.358957
# 6  Temps des Délices, 85, Rue Jean Jaurès, Villej...  48.792273   2.366928
# 7  95, Rue du Génie, Coteau - Malassis, Vitry-sur...  48.793160   2.374899
# 8  Collège Lakanal, 11, Rue Lakanal, Coteau - Mal...  48.794048   2.382871
# 9  55, Rue Charles Infroit, Le Fort, Vitry-sur-Se...  48.794935   2.390843
#
#                X             Y  Distance from center
# 0 -430409.748445  5.481822e+06           7762.087348
# 1 -429809.748445  5.481822e+06           7510.659092
# 2 -429209.748445  5.481822e+06           7300.000000
# 3 -428609.748445  5.481822e+06           7133.722731
# 4 -428009.748445  5.481822e+06           7014.983963
# 5 -427409.748445  5.481822e+06           6946.221995
# 6 -426809.748445  5.481822e+06           6928.924881
# 7 -426209.748445  5.481822e+06           6963.476143
# 8 -425609.748445  5.481822e+06           7049.113419
# 9 -425009.748445  5.481822e+06           7184.010022

# %% [markdown]
# and let's now save/persist this data into local file.

# %%
df_locations.to_pickle('./locations.pkl')

# %%
df_locations = pd.read_pickle('./locations.pkl')

# %%
df_locations.head(2)
# Out:
#                                              Address   Latitude  Longitude  \
# 0  3, Rue du Président Roosevelt, Bourg-la-Reine,...  48.786934   2.319107
# 1  61, Avenue de la Division Leclerc, Cité-Jardin...  48.787825   2.327076
#
#                X             Y  Distance from center
# 0 -430409.748445  5.481822e+06           7762.087348
# 1 -429809.748445  5.481822e+06           7510.659092

# %% [markdown]
# ## Foursquare

# %% [markdown]
# Once we have our data_set built, We're ready to explore each area using Foursquare, we will pass ours credentials and we will explore each area using its cordinates and we will retrieve all the hotels located in each Area

# %%
CLIENT_ID = 'GKSVXMYQIKGQPZITFL52DOFLR0IYIB0IYVETAHC0F1HFZNVV' # your Foursquare ID
CLIENT_SECRET = 'A2ZBBMH5MAC1HIBTKX2FO1QZSTCILJ3HC0XP5QFALQ0GLS5A' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: GKSVXMYQIKGQPZITFL52DOFLR0IYIB0IYVETAHC0F1HFZNVV
# CLIENT_SECRET:A2ZBBMH5MAC1HIBTKX2FO1QZSTCILJ3HC0XP5QFALQ0GLS5A

# %% [markdown]
# Before we retrieve the locations for all of our areas, lets take a look of the API response for each area, we will take the cordinates of the city center and call the API

# %%
# type your answer here
LIMIT = 100
radius = circle_diameter/2
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=GKSVXMYQIKGQPZITFL52DOFLR0IYIB0IYVETAHC0F1HFZNVV&client_secret=A2ZBBMH5MAC1HIBTKX2FO1QZSTCILJ3HC0XP5QFALQ0GLS5A&ll=48.85293705,2.3500501225000026&v=20180605&radius=300.0&limit=100'

# %%
results = requests.get(url).json()
#results

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#                                           name           categories  \
# 0       Parvis Notre-Dame — Place Jean-Paul II                Plaza
# 1   Tours de la Cathédrale Notre-Dame de Paris       Scenic Lookout
# 2                        Shakespeare & Company            Bookstore
# 3                      Au Vieux Paris d'Arcole    French Restaurant
# 4                                         Sola  Japanese Restaurant
# 5                               Comme chai Toi    French Restaurant
# 6                            Square Jean XXIII                 Park
# 7               A. Lacroix Pâtissier & Glacier          Pastry Shop
# 8                            Le Petit Châtelet    French Restaurant
# 9                     Sourire Tapas Françaises     Tapas Restaurant
# 10                                    Loubnane  Lebanese Restaurant
# 11                         Square René Viviani               Garden
# 12                              Le Saint-Régis               Bistro
# 13               Berges de Seine – Rive droite     Pedestrian Plaza
# 14                  Hayaku Shop Libraire Manga            Bookstore
# 15             Brasserie de l'Isle Saint-Louis            Brasserie
#
#           lat       lng
# 0   48.853407  2.348456
# 1   48.853230  2.349207
# 2   48.852568  2.347096
# 3   48.854196  2.350312
# 4   48.851569  2.348391
# 5   48.851749  2.349319
# 6   48.852499  2.351375
# 7   48.851714  2.349406
# 8   48.852637  2.346919
# 9   48.851167  2.347728
# 10  48.851237  2.347605
# 11  48.852249  2.347630
# 12  48.852930  2.353724
# 13  48.855131  2.352289
# 14  48.851350  2.346836
# 15  48.853050  2.353402

# %% [markdown]
# We can see that we got 15 locations, that number is not even close to the max number of locs we can get, 100, and being the center we can assume that not other area will be get much more closer than that and wont have any risk of loosing any Hotel while calling the Geopy API

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, X, Y, dist_center, radius=circle_diameter/2):
    
    venues_list=[]
    index = 0
    for name, lat, lng, x, y, dist in zip(names, latitudes, longitudes, X, Y, dist_center):
        print('{}){}'.format(index, name) )
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            x, 
            y, 
            dist,
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
        
        index = index + 1
        if lat == latitudes.iloc[-1]:
            print("DONE")

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'X',
                  'Y',
                  'Distance from center',           
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    
    return(nearby_venues)

# %%
paris_locs_areas = getNearbyVenues(names=df_locations['Address'], 
                                latitudes=df_locations['Latitude'], 
                                longitudes=df_locations['Longitude'],
                                X=df_locations['X'],
                                Y=df_locations['Y'],
                                dist_center=df_locations['Distance from center']
                                  )
# Out:
# 0)3, Rue du Président Roosevelt, Bourg-la-Reine, Antony, Hauts-de-Seine, Île-de-France, France métropolitaine, 92340, France
# 1)61, Avenue de la Division Leclerc, Cité-Jardins, Cachan, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94230, France
# 2)36, Allée Eugène Belgrand, Cachan, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94230, France
# 3)Rue de la Concorde, Cachan, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94230, France
# 4)7, Allée Sonia Delaunay, Villejuif, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94800, France
# 5)Centre Hospitalier Paul Guiraud, Avenue de la République, Villejuif, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94800, France
# 6)Temps des Délices, 85, Rue Jean Jaurès, Villejuif, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94800, France
# 7)95, Rue du Génie, Coteau - Malassis, Vitry-sur-Seine, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94400, France
# 8)Collège Lakanal, 11, Rue Lakanal, Coteau - Malassis, Vitry-sur-Seine, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94400, France
# 9)55, Rue Charles Infroit, Le Fort, Vitry-sur-Seine, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94400, France
# 10)23, Rue Neuve, Gare - Jean Jaurès, Vitry-sur-Seine, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94400, France
# 11)25, Rue George Sand, Port à l'Anglais, Vitry-sur-Seine, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94400, France
# 12)Funérarium, Quai Jules Guesde, Port à l'Anglais, Vitry-sur-Seine, Arrondissement de L'Haÿ-les-Roses, Val-de-Marne, Île-de-France, France métropolitaine, 94400, France
# 13)4, Square Fernand Léger, Résidence du Port Galand, Bagneux, Antony, Hauts-de-Seine, Île-de-France, France métropolitaine, 92220, France
# 14)Allée Mirabeau, Résidence du Port Galand, Bagneux, Antony, Hauts-de-Seine, Île-de-France, France métropolitaine, 92220, France
#
Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93200, France
# 618)Le Jade, Rue Federico Fellini, La Plaine Saint-Denis, La Plaine, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93210, France
# 619)1;1b, Avenue Henri Rol-Tanguy, La Plaine Saint-Denis, La Plaine, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93210, France
# 620)109, Rue du Port, Landy-Plaine - Marcreus - Pressensé, Aubervilliers, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93300, France
# 621)1, Passage des Francs Tireurs, Landy-Plaine - Marcreus - Pressensé, Aubervilliers, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93300, France
# 622)Association des Parents d'Élèves des Grésillons (APEGRE), Rue François Kovac, Les Grésillons, Gennevilliers, Arrondissement de Nanterre, Hauts-de-Seine, Île-de-France, France métropolitaine, 92230, France
# 623)Leaders Opticom, 5, Rue Henri Bergson, Grésillons, Asnières-sur-Seine, Arrondissement de Nanterre, Hauts-de-Seine, Île-de-France, France métropolitaine, 92600, France
# 624)École primaire Elisabeth Badinter, Rue Sarah Bernhardt, Grésillons, Asnières-sur-Seine, Arrondissement de Nanterre, Hauts-de-Seine, Île-de-France, France métropolitaine, 92600, France
# 625)Centre Sportif de l'Ile des Vannes, Quai de Seine, Les Docks, Saint-Ouen-sur-Seine, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93400, France
# 626)Parc d'Activités Rives de Seine, Saint-Ouen-sur-Seine, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93400, France
# 627)Électricité de France, Allée de Seine, Pleyel - Confluence, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93200, France
# 628)Rue Camille Moke, Pleyel - Confluence, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93210, France
# 629)A 86, La Plaine Saint-Denis, La Plaine, Saint-Denis, Seine-Saint-Denis, Île-de-France, France métropolitaine, 93200, France
# DONE

# %%
paris_locs_areas.head(10)
# Out:
#                                         Neighborhood  Neighborhood Latitude  \
# 0  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 1  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 2  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 3  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 4  61, Avenue de la Division Leclerc, Cité-Jardin...              48.787825
# 5  61, Avenue de la Division Leclerc, Cité-Jardin...              48.787825
# 6  61, Avenue de la Division Leclerc, Cité-Jardin...              48.787825
# 7  7, Allée Sonia Delaunay, Villejuif, Arrondisse...              48.790495
# 8  7, Allée Sonia Delaunay, Villejuif, Arrondisse...              48.790495
# 9  7, Allée Sonia Delaunay, Villejuif, Arrondisse...              48.790495
#
#    Neighborhood Longitude              X             Y  Distance from center  \
# 0                2.319107 -430409.748445  5.481822e+06           7762.087348
# 1                2.319107 -430409.748445  5.481822e+06           7762.087348
# 2                2.319107 -430409.748445  5.481822e+06           7762.087348
# 3                2.319107 -430409.748445  5.481822e+06           7762.087348
# 4                2.327076 -429809.748445  5.481822e+06           7510.659092
# 5                2.327076 -429809.748445  5.481822e+06           7510.659092
# 6                2.327076 -429809.748445  5.481822e+06           7510.659092
# 7                2.350986 -428009.748445  5.481822e+06           7014.983963
# 8                2.350986 -428009.748445  5.481822e+06           7014.983963
# 9                2.350986 -428009.748445  5.481822e+06           7014.983963
#
#                                                Venue  Venue Latitude  \
# 0                                             Fou Lo       48.785442
# 1                                     Domino's Pizza       48.787782
# 2                     Sanitaire Installation Moderne       48.786469
# 3  Arrêt Place de la Résistance - Charles de Gaul...       48.786512
# 4                   Piscine Intercommunale de Cachan       48.786616
# 5                                 Stade Léo Lagrange       48.785574
# 6                                   Autolib' Station       48.785661
# 7                                          La Fabrik       48.791494
# 8                                Place Pablo Picasso       48.790130
# 9                   Aire de jeux des hautes bruyeres       48.792107
#
#    Venue Longitude       Venue Category
# 0         2.317927     Asian Restaurant
# 1         2.318917          Pizza Place
# 2         2.318365    Other Repair Shop
# 3         2.317919             Bus Stop
# 4         2.327954                 Pool
# 5         2.326525   Athletics & Sports
# 6         2.328780  Rental Car Location
# 7         2.353263           Non-Profit
# 8         2.350865                Plaza
# 9         2.352126           Playground

# %%
paris_locs_areas.to_pickle('./paris_venues.pkl')

# %%
paris_locs_areas = pd.read_pickle('./paris_venues.pkl')

# %%
paris_locs_areas.head()
# Out:
#                                         Neighborhood  Neighborhood Latitude  \
# 0  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 1  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 2  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 3  3, Rue du Président Roosevelt, Bourg-la-Reine,...              48.786934
# 4  61, Avenue de la Division Leclerc, Cité-Jardin...              48.787825
#
#    Neighborhood Longitude              X             Y  Distance from center  \
# 0                2.319107 -430409.748445  5.481822e+06           7762.087348
# 1                2.319107 -430409.748445  5.481822e+06           7762.087348
# 2                2.319107 -430409.748445  5.481822e+06           7762.087348
# 3                2.319107 -430409.748445  5.481822e+06           7762.087348
# 4                2.327076 -429809.748445  5.481822e+06           7510.659092
#
#                                                Venue  Venue Latitude  \
# 0                                             Fou Lo       48.785442
# 1                                     Domino's Pizza       48.787782
# 2                     Sanitaire Installation Moderne       48.786469
# 3  Arrêt Place de la Résistance - Charles de Gaul...       48.786512
# 4                   Piscine Intercommunale de Cachan       48.786616
#
#    Venue Longitude     Venue Category
# 0         2.317927   Asian Restaurant
# 1         2.318917        Pizza Place
# 2         2.318365  Other Repair Shop
# 3         2.317919           Bus Stop
# 4         2.327954               Pool

# %%
paris_locs_areas.shape
# Out:
# (8823, 10)

# %% [markdown]
# Before we explore the Venue's Categories we will remove all the venues that are a restaurant and after that we will track the venues that are similitar to an Hotel but are not defined as one

# %%
paris_locs_areas = paris_locs_areas.drop( paris_locs_areas[paris_locs_areas['Venue Category'].str.contains('restaurant', case=False)].index    )

# %%
paris_locs_areas.shape
# Out:
# (5821, 10)

# %%
paris_locs_areas = paris_locs_areas.drop( paris_locs_areas[paris_locs_areas['Venue Category'].str.contains('store', case=False)].index    )

# %%
paris_locs_areas.shape
# Out:
# (5363, 10)

# %%
paris_locs_areas = paris_locs_areas.drop( paris_locs_areas[paris_locs_areas['Venue Category'].str.contains('shop', case=False)].index    )

# %%
paris_locs_areas.shape
# Out:
# (4748, 10)

# %% [markdown]
# We just got rid of almost 3K rows

# %%
pd.unique(paris_locs_areas['Venue Category'])
# Out:
# array(['Pizza Place', 'Bus Stop', 'Pool', 'Athletics & Sports',
#        'Rental Car Location', 'Non-Profit', 'Plaza', 'Playground',
#        'Funeral Home', 'Concert Hall', 'Bakery', 'Supermarket',
#        'Speakeasy', 'Home Service', 'Bus Station', 'Gastropub',
#        'Science Museum', 'Theater', 'Art Gallery', 'Gym', 'Pharmacy',
#        'Boarding House', 'Trail', 'Bank', 'Hotel', 'Gym / Fitness Center',
#        'Tennis Court', 'Construction & Landscaping', 'Park',
#        'Metro Station', 'Performing Arts Venue', 'Bed & Breakfast',
#        'Harbor / Marina', 'Train Station', 'Café', 'Movie Theater',
#        'Stadium', 'Farmers Market', 'Motel', 'Bistro', 'Climbing Gym',
#        'Event Space', 'Arcade', 'Boat or Ferry', 'Flea Market',
#        'Gas Station', 'Brasserie', 'Comedy Club', 'Creperie',
#        'Sports Club', 'Skate Park', 'Track Stadium', 'Basketball Stadium',
#        'Organic Grocery', 'Bar', 'Dive Bar', 'General Entertainment',
#        'Tram Station', 'Food Court', 'Bike Rental / Bike Share',
#        'Gym Pool', 'Wine Bar', 'Sandwich Place', 'Steakhouse', 'Hostel',
#        'Music Venue', 'Fried Chicken Joint', 'Basketball Court', 'Diner',
#        'Garden Center', 'Garden', 'Food Truck', 'Soccer Stadium',
#        'Taco Place', 'Hookah Bar', 'Soccer Field', 'Laser Tag', 'Market',
#        'Multiplex', 'Scenic Lookout', 'Farm', 'Travel & Transport',
#        'Recording Studio', 'BBQ Joint', 'Pub', 'Squash Court',
#        'Art Museum', 'Hotel Bar', 'Football Stadium', 'Breakfast Spot',
#        'Lounge', 'Nightclub', 'Cafeteria', 'Photography Studio',
#        'Beer Garden', 'Cycle Studio', 'Street Art', 'Cultural Center',
#        'Burger Joint', 'Butcher', 'Juice Bar', 'Lake', 'Zoo',
#        'Monument / Landmark', 'Forest', 'Recreation Center', 'Locksmith',
#        'National Park', 'Tennis Stadium', 'Bike Trail', 'Dry Cleaner',
#        'Outdoors & Recreation', 'Martial Arts School',
#        'EV Charging Station', 'Tea Room', 'Museum', 'Pedestrian Plaza',
#        'Night Market', 'History Museum', 'Aquarium', 'Zoo Exhibit',
#        'Botanical Garden', 'Salad Place', 'Resort', 'Road',
#        'Theme Park Ride / Attraction', 'Beer Bar', 'Tunnel', 'Spa',
#        'Track', 'Castle', 'Historic Site', 'Sports Bar', 'Jazz Club',
#        'Noodle House', 'Planetarium', 'Cocktail Bar',
#        'Indie Movie Theater', 'Gaming Cafe',
#        'Residential Building (Apartment / Condo)',
#        'Health & Beauty Service', 'Skating Rink', 'Laundromat',
#        'Heliport', 'Water Park', 'Bus Line', 'Lyonese Bouchon',
#        'Fountain', 'Yoga Studio', 'Church', 'Snack Place', 'Newsstand',
#        'Deli / Bodega', 'Mac & Cheese Joint', 'Soup Place', 'Building',
#        'Photography Lab', 'Pool Hall', 'Government Building',
#        'College Cafeteria', 'Pet Café', 'Poke Place', 'Escape Room',
#        'Dance Studio', 'Parking', 'Bridge', 'Canal Lock', 'Burrito Place',
#        'Indoor Play Area', 'Film Studio', 'Boutique', 'Waterfront',
#        'Library', 'Opera House', 'Tech Startup', 'Roof Deck',
#        'Coworking Space', 'Brewery', 'Rugby Stadium', 'Outdoor Sculpture',
#        'Bowling Alley', 'Gay Bar', 'Memorial Site', 'Fish Market',
#        'Cemetery', 'Office', 'Auto Garage', 'Racecourse', 'Island',
#        'Radio Station', 'Exhibit', 'Sculpture Garden', 'Internet Cafe',
#        'Trattoria/Osteria', 'Circus', 'Rock Club', 'Nature Preserve',
#        'Champagne Bar', 'Beach Bar', 'General College & University',
#        'Tattoo Parlor', 'Karaoke Bar', 'Street Food Gathering', 'Dog Run',
#        'Business Service', 'Boxing Gym', 'Arts & Entertainment', 'Canal',
#        'Food', 'Irish Pub', 'Insurance Office', 'Hot Dog Joint', 'Lawyer',
#        'Medical Center', 'College Theater', 'Massage Studio',
#        'Tourist Information Center', 'Food Service', 'Design Studio',
#        'Piano Bar', 'Stables', 'Distillery', 'Dive Spot', 'Bowling Green',
#        'Vineyard', 'Public Art', 'Wings Joint', 'Auto Dealership',
#        'Circus School'], dtype=object)

# %% [markdown]
# We will get all rows wich fit in one of the Categories above:
# Boarding House, Hotel, Bed & Breakfast, Hostel, Hotel Bar

# %%
paris_hotels = paris_locs_areas[ (paris_locs_areas['Venue Category'].str.contains('hotel', case=False)) |
                      (paris_locs_areas['Venue Category'].str.contains('boarding house', case=False)) |
                     (paris_locs_areas['Venue Category'].str.contains('bed & breakfast', case=False)) |
                     (paris_locs_areas['Venue Category'].str.contains('hostel', case=False)) |
                     (paris_locs_areas['Venue Category'].str.contains('hotel bar', case=False)) 
                                                                                                        ]
paris_hotels.reset_index(inplace=True)
paris_hotels.head()
# Out:
#    index                                       Neighborhood  \
# 0     32  2, Rue d'Estienne d'Orves, Cité-Jardins, Cacha...
# 1     42  Rue François Delage, Cachan, Arrondissement de...
# 2     60  3, Rue Jules Ferry, Gare - Jean Jaurès, Vitry-...
# 3     74  Promenade des Vallons de la Bièvre, La Coulée ...
# 4     95  6 bis, Impasse Guyton de Morveau, Arcueil, Arr...
#
#    Neighborhood Latitude  Neighborhood Longitude              X             Y  \
# 0              48.791940                2.321924 -430109.748445  5.482342e+06
# 1              48.793721                2.337864 -428909.748445  5.482342e+06
# 2              48.800825                2.401641 -424109.748445  5.482342e+06
# 3              48.793377                2.292861 -432209.748445  5.482861e+06
# 4              48.798727                2.340683 -428609.748445  5.482861e+06
#
#    Distance from center                           Venue  Venue Latitude  \
# 0           7163.099888              Séjours & Affaires       48.793935
# 1           6713.419397                   Comfort Hotel       48.795742
# 2           6993.568474         La Maison Bacana, Paris       48.800733
# 3           7922.752047  La Roseraie - Hôtel Restaurant       48.795232
# 4           6129.437168             Hotel Stars Arcueil       48.797979
#
#    Venue Longitude   Venue Category
# 0         2.320450   Boarding House
# 1         2.335694            Hotel
# 2         2.400948  Bed & Breakfast
# 3         2.291929            Hotel
# 4         2.343970            Hotel

# %%
paris_hotels.drop('index', axis=1, inplace=True)
paris_hotels.head()
# Out:
# C:\Users\Alvaro Zamedio\.conda\envs\data_test1\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                         Neighborhood  Neighborhood Latitude  \
# 0  2, Rue d'Estienne d'Orves, Cité-Jardins, Cacha...              48.791940
# 1  Rue François Delage, Cachan, Arrondissement de...              48.793721
# 2  3, Rue Jules Ferry, Gare - Jean Jaurès, Vitry-...              48.800825
# 3  Promenade des Vallons de la Bièvre, La Coulée ...              48.793377
# 4  6 bis, Impasse Guyton de Morveau, Arcueil, Arr...              48.798727
#
#    Neighborhood Longitude              X             Y  Distance from center  \
# 0                2.321924 -430109.748445  5.482342e+06           7163.099888
# 1                2.337864 -428909.748445  5.482342e+06           6713.419397
# 2                2.401641 -424109.748445  5.482342e+06           6993.568474
# 3                2.292861 -432209.748445  5.482861e+06           7922.752047
# 4                2.340683 -428609.748445  5.482861e+06           6129.437168
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0              Séjours & Affaires       48.793935         2.320450
# 1                   Comfort Hotel       48.795742         2.335694
# 2         La Maison Bacana, Paris       48.800733         2.400948
# 3  La Roseraie - Hôtel Restaurant       48.795232         2.291929
# 4             Hotel Stars Arcueil       48.797979         2.343970
#
#     Venue Category
# 0   Boarding House
# 1            Hotel
# 2  Bed & Breakfast
# 3            Hotel
# 4            Hotel

# %%
paris_hotels.shape
# Out:
# (743, 10)

# %%
df_hotels_only = paris_hotels[['Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']]

# %%
df_hotels_only.head()
# Out:
#                             Venue  Venue Latitude  Venue Longitude  \
# 0              Séjours & Affaires       48.793935         2.320450
# 1                   Comfort Hotel       48.795742         2.335694
# 2         La Maison Bacana, Paris       48.800733         2.400948
# 3  La Roseraie - Hôtel Restaurant       48.795232         2.291929
# 4             Hotel Stars Arcueil       48.797979         2.343970
#
#     Venue Category
# 0   Boarding House
# 1            Hotel
# 2  Bed & Breakfast
# 3            Hotel
# 4            Hotel

# %%
def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

# %%
def get_X_Y_values(Latitudes, Longitudes):
    Xs = []
    Ys = []
    
    for lat, lon in zip(Latitudes, Longitudes):
        xx, yy = lonlat_to_xy(lon=lon, lat=lat)
        Xs.append(xx)
        Ys.append(yy)
        
    return Xs, Ys

# %%
Xs_venues, Ys_venues = get_X_Y_values(df_hotels_only['Venue Latitude'], df_hotels_only['Venue Longitude'])
# Out:
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# ...
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-3-7b1794dfb3b4>:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)

# %%
len(Xs_venues)
# Out:
# 743

# %%
df_hotels_only['X'] = Xs_venues
df_hotels_only['Y'] = Ys_venues
# Out:
# <ipython-input-146-cf3f5b46be3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hotels_only['X'] = Xs_venues
# <ipython-input-146-cf3f5b46be3c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hotels_only['Y'] = Ys_venues

# %%
df_hotels_only.head()
# Out:
#                             Venue  Venue Latitude  Venue Longitude  \
# 0              Séjours & Affaires       48.793935         2.320450
# 1                   Comfort Hotel       48.795742         2.335694
# 2         La Maison Bacana, Paris       48.800733         2.400948
# 3  La Roseraie - Hôtel Restaurant       48.795232         2.291929
# 4             Hotel Stars Arcueil       48.797979         2.343970
#
#     Venue Category              X             Y
# 0   Boarding House -430180.205119  5.482581e+06
# 1            Hotel -429030.705448  5.482592e+06
# 2  Bed & Breakfast -424162.179480  5.482340e+06
# 3            Hotel -432243.148458  5.483078e+06
# 4            Hotel -428383.190997  5.482738e+06

# %%
paris_hotel_group = paris_hotels[['Neighborhood', 'Neighborhood Latitude', 
    'Neighborhood Longitude', 'X', 'Y', 'Distance from center', 'Venue']].groupby(['Neighborhood', 'Neighborhood Latitude',
                                                                          'Neighborhood Longitude', 'X', 'Y', 'Distance from center']).agg(['count'])

# %%
paris_hotel_group.reset_index(inplace=True)
paris_hotel_group.head(10)
# Out:
#   index                                       Neighborhood  \
#
# 0     0  1, Rue Le Brun, Quartier de la Salpêtrière, Pa...
# 1     1  1, Square Paul Blanchet, Quartier du Bel-Air, ...
# 2     2  1, Villa Edgar Quinet, Garibaldi, Saint-Ouen-s...
# 3     3  1, Villa Marie Vassilieff, Quartier Necker, Pa...
# 4     4  10, Passage Turquetil, Quartier Sainte-Marguer...
# 5     5  10, Rue Gaston Paymal, Clichy, Arrondissement ...
# 6     6  10, Rue Jean Giraudoux, Quartier de Chaillot, ...
# 7     7  10, Rue Lecuirot, Plaisance, Quartier de Plais...
# 8     8  10, Rue d'Arcueil, Quartier Ferry-Buffalo, Mon...
# 9     9  10, Rue de l'Abbaye, Quartier de Saint-Germain...
#
#   Neighborhood Latitude Neighborhood Longitude              X             Y  \
#
# 0             48.837883               2.355272 -426809.748445  5.487018e+06
# 1             48.834087               2.405473 -423209.748445  5.485979e+06
# 2             48.905847               2.333739 -427109.748445  5.494813e+06
# 3             48.843441               2.321023 -429209.748445  5.488058e+06
# 4             48.851447               2.392840 -423809.748445  5.488058e+06
# 5             48.903169               2.309776 -428909.748445  5.494813e+06
# 6             48.869015               2.298032 -430409.748445  5.491175e+06
# 7             48.829314               2.320544 -429509.748445  5.486499e+06
# 8             48.811073               2.325221 -429509.748445  5.484420e+06
# 9             48.854345               2.334641 -428009.748445  5.489097e+06
#
#   Distance from center Venue
#                        count
# 0          1734.935157     3
# 1          4622.769733     3
# 2          6065.476074     1
# 3          2402.082430     2
# 4          3176.476035     2
# 5          6383.572667     2
# 6          4257.933771    17
# 7          3439.476704     5
# 8          5050.742520     1
# 9          1153.256259     4

# %%
paris_hotel_group.shape
# Out:
# (253, 8)

# %%
def get_minimum_distance_to_hotel(X1, Y1, X2, Y2):
   
    minimum_distances = []
    
    for x1, y1  in zip(X1, Y1):
        min_dist = 10000000000000
        for x2, y2 in zip(X2, Y2):
            dist = calc_xy_distance(x1, y1, x2, y2)
            if dist < min_dist:
                min_dist = dist
        minimum_distances.append(min_dist)
        
    return minimum_distances

# %%
distances_to_hotels = get_minimum_distance_to_hotel(paris_hotel_group['X'], paris_hotel_group['Y'], Xs_venues, Ys_venues)

# %%
distances_to_hotels[0:11]
# Out:
# [24.147417355783208,
#  111.54049212719345,
#  147.26284335541084,
#  171.04647130099636,
#  98.23582500252003,
#  225.1908588101217,
#  28.518158246452,
#  84.54645169371065,
#  238.43632316600238,
#  96.15518330974203,
#  247.9733069649845]

# %%
paris_hotel_group['Closest Hotel'] = distances_to_hotels

# %%
paris_hotel_group.head()
# Out:
#   index                                       Neighborhood  \
#
# 0     0  1, Rue Le Brun, Quartier de la Salpêtrière, Pa...
# 1     1  1, Square Paul Blanchet, Quartier du Bel-Air, ...
# 2     2  1, Villa Edgar Quinet, Garibaldi, Saint-Ouen-s...
# 3     3  1, Villa Marie Vassilieff, Quartier Necker, Pa...
# 4     4  10, Passage Turquetil, Quartier Sainte-Marguer...
#
#   Neighborhood Latitude Neighborhood Longitude              X             Y  \
#
# 0             48.837883               2.355272 -426809.748445  5.487018e+06
# 1             48.834087               2.405473 -423209.748445  5.485979e+06
# 2             48.905847               2.333739 -427109.748445  5.494813e+06
# 3             48.843441               2.321023 -429209.748445  5.488058e+06
# 4             48.851447               2.392840 -423809.748445  5.488058e+06
#
#   Distance from center Venue Closest Hotel
#                        count
# 0          1734.935157     3     24.147417
# 1          4622.769733     3    111.540492
# 2          6065.476074     1    147.262843
# 3          2402.082430     2    171.046471
# 4          3176.476035     2     98.235825

# %%
paris_hotel_group.to_pickle('./paris_hotels_groups.pkl')

# %%
paris_hotel_group = pd.read_pickle('./paris_hotels_groups.pkl')

# %%
paris_hotel_group.head()
# Out:
#   index                                       Neighborhood  \
#
# 0     0  1, Rue Le Brun, Quartier de la Salpêtrière, Pa...
# 1     1  1, Square Paul Blanchet, Quartier du Bel-Air, ...
# 2     2  1, Villa Edgar Quinet, Garibaldi, Saint-Ouen-s...
# 3     3  1, Villa Marie Vassilieff, Quartier Necker, Pa...
# 4     4  10, Passage Turquetil, Quartier Sainte-Marguer...
#
#   Neighborhood Latitude Neighborhood Longitude              X             Y  \
#
# 0             48.837883               2.355272 -426809.748445  5.487018e+06
# 1             48.834087               2.405473 -423209.748445  5.485979e+06
# 2             48.905847               2.333739 -427109.748445  5.494813e+06
# 3             48.843441               2.321023 -429209.748445  5.488058e+06
# 4             48.851447               2.392840 -423809.748445  5.488058e+06
#
#   Distance from center Venue Closest Hotel
#                        count
# 0          1734.935157     3     24.147417
# 1          4622.769733     3    111.540492
# 2          6065.476074     1    147.262843
# 3          2402.082430     2    171.046471
# 4          3176.476035     2     98.235825

# %%
paris_hotel_group.columns = ['index', 'Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'X', 'Y', 'Distance from center', 'Hotels nearby', 'Closest Hotel' ]
paris_hotel_group.head()
# Out:
#    index                                       Neighborhood  \
# 0      0  1, Rue Le Brun, Quartier de la Salpêtrière, Pa...
# 1      1  1, Square Paul Blanchet, Quartier du Bel-Air, ...
# 2      2  1, Villa Edgar Quinet, Garibaldi, Saint-Ouen-s...
# 3      3  1, Villa Marie Vassilieff, Quartier Necker, Pa...
# 4      4  10, Passage Turquetil, Quartier Sainte-Marguer...
#
#    Neighborhood Latitude  Neighborhood Longitude              X             Y  \
# 0              48.837883                2.355272 -426809.748445  5.487018e+06
# 1              48.834087                2.405473 -423209.748445  5.485979e+06
# 2              48.905847                2.333739 -427109.748445  5.494813e+06
# 3              48.843441                2.321023 -429209.748445  5.488058e+06
# 4              48.851447                2.392840 -423809.748445  5.488058e+06
#
#    Distance from center  Hotels nearby  Closest Hotel
# 0           1734.935157              3      24.147417
# 1           4622.769733              3     111.540492
# 2           6065.476074              1     147.262843
# 3           2402.082430              2     171.046471
# 4           3176.476035              2      98.235825

# %%
paris_hotel_group.drop('index', axis=1, inplace=True)

# %%
pd.unique(paris_hotel_group['Hotels nearby'])
# Out:
# array([ 3,  1,  2, 17,  5,  4,  7,  8, 12, 11,  6, 10,  9, 23, 14, 16],
#       dtype=int64)

# %% [markdown]
# So, our conditions to pick a place will be:
# * It cant be no more than 6 hotels in the area
# * It must be 5km away from the center city maximum
# * The closest hotel must be 100m away at minimum

# %%
paris_hotel_group.shape
# Out:
# (253, 8)

# %%
paris_hotels_filter = paris_hotel_group[ (paris_hotel_group['Hotels nearby']<=6) &
                                        (paris_hotel_group['Distance from center']<=5000) &
                                        (paris_hotel_group['Closest Hotel']<=100) 
                                           ]
paris_hotels_filter.reset_index(inplace=True)
paris_hotels_filter.drop('index', axis=1, inplace=True)
paris_hotels_filter.shape
# Out:
# C:\Users\Alvaro Zamedio\.conda\envs\data_test1\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (27, 8)

# %%
paris_hotels_filter.head()
# Out:
#                                         Neighborhood  Neighborhood Latitude  \
# 0  1, Rue Le Brun, Quartier de la Salpêtrière, Pa...              48.837883
# 1  10, Passage Turquetil, Quartier Sainte-Marguer...              48.851447
# 2  10, Rue Lecuirot, Plaisance, Quartier de Plais...              48.829314
# 3  10, Rue de l'Abbaye, Quartier de Saint-Germain...              48.854345
# 4  12, Rue Beautreillis, Quartier de l'Arsenal, P...              48.852899
#
#    Neighborhood Longitude              X             Y  Distance from center  \
# 0                2.355272 -426809.748445  5.487018e+06           1734.935157
# 1                2.392840 -423809.748445  5.488058e+06           3176.476035
# 2                2.320544 -429509.748445  5.486499e+06           3439.476704
# 3                2.334641 -428009.748445  5.489097e+06           1153.256259
# 4                2.363740 -425909.748445  5.488577e+06           1014.889157
#
#    Hotels nearby  Closest Hotel
# 0              3      24.147417
# 1              2      98.235825
# 2              5      84.546452
# 3              4      96.155183
# 4              4      54.132195

# %%
latitude, longitude =  paris_center[0], paris_center[1]
map_paris_hotels = folium.Map(location=[latitude, longitude], zoom_start=13)
folium.Marker(location=[latitude, longitude], popup='Notre-Dame').add_to(map_paris_hotels)
#folium.TileLayer('cartodbpositron').add_to(map_paris_hotels)
latitudes = paris_hotels_filter['Neighborhood Latitude'].to_list()
longitudes = paris_hotels_filter['Neighborhood Longitude'].to_list()
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_berlin) 
    folium.Circle([lat, lon], radius=300, color='red', fill=False).add_to(map_paris_hotels)
    #folium.Marker([lat, lon]).add_to(map_berlin)
map_paris_hotels
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b6fae8e306224a199e38fa35c7a1d1b3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b6fae8e306224a199e38fa35c7a1d1b3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b6fae8e306224a199e38fa35c7a1d1b3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b6fae8e306224a199e38fa35c7a1d1b3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.85293705%2C%202.3500501225000026%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
from sklearn.cluster import KMeans

number_of_clusters = 15

good_xys = paris_hotels_filter[['X', 'Y']].values
kmeans = KMeans(n_clusters=number_of_clusters, random_state=0).fit(good_xys)

cluster_centers = [xy_to_lonlat(cc[0], cc[1]) for cc in kmeans.cluster_centers_]
# Out:
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
# <ipython-input-3-7b1794dfb3b4>:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)

# %%
good_latitudes =  paris_hotels_filter['Neighborhood Latitude'].values
good_longitudes =  paris_hotels_filter['Neighborhood Longitude'].values
good_locations = [[lat, lon] for lat, lon in zip(good_latitudes, good_longitudes)]

# %%
from folium.plugins import HeatMap
map_paris_hotels = folium.Map(location=[latitude, longitude], zoom_start=13)
#folium.TileLayer('cartodbpositron').add_to(map_berlin)
HeatMap(good_locations, radius=25).add_to(map_paris_hotels)
folium.Circle(location=[latitude, longitude], radius=2500, color='white', fill=True, fill_opacity=0.4).add_to(map_paris_hotels)
folium.Marker(location=[latitude, longitude], popup='Notre-Dame').add_to(map_paris_hotels)
for lon, lat in cluster_centers:
    folium.Circle([lat, lon], radius=500, color='green', fill=True, fill_opacity=0.25).add_to(map_paris_hotels) 
for lat, lon in zip(latitudes, longitudes):
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_paris_hotels)
map_paris_hotels
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2604b2f5ae1e49f4a0676a4d20121a60%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2604b2f5ae1e49f4a0676a4d20121a60%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2604b2f5ae1e49f4a0676a4d20121a60%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2604b2f5ae1e49f4a0676a4d20121a60%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...
